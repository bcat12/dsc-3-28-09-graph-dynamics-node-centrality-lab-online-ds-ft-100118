# %% [markdown]
# # Network Dynamics: Node Centrality - Lab
#
# ## Introduction
# In this lab, we shall put the node centrality measures in to practice to analyze the character interactions in graph structure from the popular series of novels called ""A Song of Ice and Fire" by George R. R. Martin. The of famous HBO series "Game of Thrones" is derived from this saga. In this lab, we shall calculate different centrality measures to identify the the importance of characters as the story progresses.
#
#
# ## Objectives
# You will be able to:
# - Understand and explain network centrality and its importance in graph analysis
# - Understand and calculate Degree, Closeness, Betweenness and Eigenvector centrality measures
# - Describe the use case for several centrality measures

# %% [markdown]
# ## ASIOF (A Song of Ice and Fire) Character Interaction Graph Data
#
# A. J. Beveridge, and J. Shan  created a network from books "A song of ice and fire" by extracting relationships between characters of the story. [The dataset is available at Github](https://github.com/mathbeveridge/asoiaf)
# as an interaction network which was built as
# > Parse the text and build a graph by connecting (creating an edge) two characters (nodes of the graph) whenever their names appear within 15 words. The edge weight corresponds to the number of interactions.
#
# <img src="parse.png" width=300>
#
# The datasets have been made available for you in the repo. You are encouraged to [visit A. J. Beveridge's blog](https://networkofthrones.wordpress.com) to see how this dataset is created, and different network analysis activities which are being performed with this dataset. The image you see below, has been created using same datasets. The blog gives you information on this and more experiments. For this lab, we shall focus more on graph analysis than visualizations.
#
# <img src="got.png" width=800>
#
# Let's get on with it.

# %% [markdown]
# ## Load necessary libraries
#
# - Let's give you a head start by loading the libraries that you might need for this experiment.

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ##  Load the dataset
#
# The dataset is available for all 5 books, with two CSV files for each book. One contains nodes data as adjacency matrix and other carries edges data as edge list, e.g. for book 1, `asoiaf-book1-edges.csv` and `asoiaf-book1-nodes.csv`. So we have 10 files in total.
#
# - Read edge data for all books into pandas dataframe:  book1_df .. book5_df.
#
# How about using a for loop to do this in one go - optional.

# %%
# Load edges into dataframes
df1 = pd.read_csv('asiof/asoiaf-book1-edges.csv')
df2 = pd.read_csv('asiof/asoiaf-book2-edges.csv')
df3 = pd.read_csv('asiof/asoiaf-book3-edges.csv')
df4 = pd.read_csv('asiof/asoiaf-book4-edges.csv')
df5 = pd.read_csv('asiof/asoiaf-book5-edges.csv')

# %% [markdown]
# ## Create Empty graph instances for each book

# %%
# Create empty instances for each book above
G1 = nx.Graph()
G2 = nx.Graph()
G3 = nx.Graph()
G4 = nx.Graph()
G5 = nx.Graph()

# %% [markdown]
# ## Create Graph
# - Read the edge lists from the dataframes above into relevant graphs.
# - inspect the contents of graph to get an idea about the data structures contained within

# %%
# Read edge lists into dataframes
for x in df1.iterrows():
    G1.add_edge(x[1]['Source'], x[1]['Target'], weight=x[1]['weight'], book=x[1]['book'])
for x in df2.iterrows():
    G2.add_edge(x[1]['Source'], x[1]['Target'], weight=x[1]['weight'], book=x[1]['book'])
for x in df3.iterrows():
    G3.add_edge(x[1]['Source'], x[1]['Target'], weight=x[1]['weight'], book=x[1]['book'])
for x in df4.iterrows():
    G4.add_edge(x[1]['Source'], x[1]['Target'], weight=x[1]['weight'], book=x[1]['book'])
for x in df5.iterrows():
    G5.add_edge(x[1]['Source'], x[1]['Target'], weight=x[1]['weight'], book=x[1]['book'])

# %% [markdown]
# ## Finding important nodes (characters)
#
# Let's use and compare different centralities measures we saw earlier to identify importance of nodes in this network. There is no one right way of calaculating it, every approach has a different meaning.
#
# ## Calculate Degree Centrality
# Degree centrality which is defined by degree of a node (number of neighbors) divided by a noramlizing factor n-1 where n is the number of nodes.
#
# - __Find the neighbours of '**Catelyn-Stark**' from book 1.__

# %%
# Neighbors for catelyn stark
list(G1.neighbors('Catelyn-Stark'))
# Out:
# ['Arya-Stark',
#  'Bran-Stark',
#  'Bronn',
#  'Brynden-Tully',
#  'Cersei-Lannister',
#  'Colemon',
#  'Donnel-Waynwood',
#  'Eddard-Stark',
#  'Edmure-Tully',
#  'Eon-Hunter',
#  'Hallis-Mollen',
#  'Hoster-Tully',
#  'Jaime-Lannister',
#  'Joffrey-Baratheon',
#  'Jon-Arryn',
#  'Jon-Snow',
#  'Jon-Umber-(Greatjon)',
#  'Luwin',
#  'Lysa-Arryn',
#  'Marillion',
#  'Masha-Heddle',
#  'Moreo-Tumitis',
#  'Mya-Stone',
#  'Mychel-Redfort',
#  'Nestor-Royce',
#  'Petyr-Baelish',
#  'Rickard-Karstark',
#  'Rickon-Stark',
#  'Robb-Stark',
#  'Robert-Arryn',
#  'Robert-Baratheon',
#  'Rodrik-Cassel',
#  'Sansa-Stark',
#  'Stevron-Frey',
#  'Theon-Greyjoy',
#  'Tyrion-Lannister',
#  'Tytos-Blackwood',
#  'Tywin-Lannister',
#  'Vardis-Egen',
#  'Varys',
#  'Walder-Frey',
#  'Wendel-Manderly',
#  'Willis-Wode']

# %% [markdown]
#  `nx.degree_centrality(graph)` returns a dictionary where keys are the nodes and values are the corresponding degree centrality.
#
# - __Find the five most and least important characters from book 1 according to degree centrality__

# %%
# Five most important characters from book 1 according to degree centrality
sorted(nx.degree_centrality(G1).items(), key=lambda x:x[1], reverse=True)[0:5]
# Out:
# [('Eddard-Stark', 0.3548387096774194),
#  ('Robert-Baratheon', 0.2688172043010753),
#  ('Tyrion-Lannister', 0.24731182795698928),
#  ('Catelyn-Stark', 0.23118279569892475),
#  ('Jon-Snow', 0.19892473118279572)]

# %%
# Five least important characters from book 1 according to degree centrality
sorted(nx.degree_centrality(G1).items(), key=lambda x:x[1])[0:5]
# Out:
# [('Clydas', 0.005376344086021506),
#  ('Arthur-Dayne', 0.005376344086021506),
#  ('Arys-Oakheart', 0.005376344086021506),
#  ('Mance-Rayder', 0.005376344086021506),
#  ('Thoros-of-Myr', 0.005376344086021506)]

# %% [markdown]
# - __Plot and explain histogram from degree centrality values, calculated from book 1, and comment on the output__

# %%
# Plot a histogram of degree centrality
plt.hist(list(nx.degree_centrality(G1).values()))
plt.xlabel('Degree Centrality')
plt.ylabel('Frequency')
plt.show()

# %%
# Your observations here 
#Nedhas the highest degree of centrality, and the majority of characters are minor characters that fall betwen 0 and.05

# %% [markdown]
# ##  Weighted Degree Centrality
#
# - Create a new centrality measure as a function, `weighted_degree_centrality(Graph)` which takes in Graph and the returns a weighted degree centrality dictionary.
#
# [Refer to this paper to get an insight into this approacj](https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0165781)
#
# Weighted degree is calculated by:
#
# 1) __Sum the weight of the all edges of a node__
#
# 2) __Normalize the weighted degree by the total weight of the graph i.e. sum of weighted degrees of all nodes__
#
# 3) __Calculated weighted degree centrality for book 1 using this function__

# %%
def weighted_degree_centrality(G):
    result = dict()
    total = 0
    for node in G.nodes():
        weight_degree = 0
        for n in G.edges([node], data=True):
            weight_degree += n[2]['weight']
        result[node] = weight_degree
        total += weight_degree
    for node, value in result.items():
        result[node] = value/total
    return result

# %%
# Uncomment below to run


plt.hist(list(weighted_degree_centrality(G1).values()))
plt.show()

# %% [markdown]
# - __Get the top 10 characters from book 1, based on weighted degree centrality and compare with the results of simple degree centrality. Record your observations below__

# %%
# Weighted DC
sorted(weighted_degree_centrality(G1,).items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [('Eddard-Stark', 0.08715720879717621),
#  ('Robert-Baratheon', 0.06387455878360032),
#  ('Jon-Snow', 0.05321748574531632),
#  ('Tyrion-Lannister', 0.044121639967417865),
#  ('Sansa-Stark', 0.03699429812652729),
#  ('Bran-Stark', 0.03604398588107521),
#  ('Catelyn-Stark', 0.03529731197393429),
#  ('Robb-Stark', 0.03502579418951941),
#  ('Daenerys-Targaryen', 0.030070594623947868),
#  ('Arya-Stark', 0.02918816182459951)]

# %%
# Un-weighted DC
sorted(nx.degree_centrality(G1).items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [('Eddard-Stark', 0.3548387096774194),
#  ('Robert-Baratheon', 0.2688172043010753),
#  ('Tyrion-Lannister', 0.24731182795698928),
#  ('Catelyn-Stark', 0.23118279569892475),
#  ('Jon-Snow', 0.19892473118279572),
#  ('Robb-Stark', 0.18817204301075272),
#  ('Sansa-Stark', 0.18817204301075272),
#  ('Bran-Stark', 0.17204301075268819),
#  ('Cersei-Lannister', 0.16129032258064518),
#  ('Joffrey-Baratheon', 0.16129032258064518)]

# %%
# Your observations here 
#The most central characters stay the same when normalized, but once we drop below 3, the positions seem to change between weighted and non weighted.

# %% [markdown]
# - __ Confirm that sum of weighted degree centralitity value for all nodes sum up to 1 i.e. normalization__

# %%
# Uncomment to run 

sum(list(weighted_degree_centrality(G1).values()))
# Out:
# 1.0000000000000002

# %% [markdown]
# ## Betweenness centrality
#
# - __Calculate the weighted and un-weighted "Betweenness" centrality for book 2, and compare top ten characters as above__
# - __Comment on the results__

# %%
# Unweighted Betweenness Centrality
sorted(nx.betweenness_centrality(G1).items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [('Eddard-Stark', 0.2696038913836117),
#  ('Robert-Baratheon', 0.21403028397371796),
#  ('Tyrion-Lannister', 0.1902124972697492),
#  ('Jon-Snow', 0.17158135899829566),
#  ('Catelyn-Stark', 0.1513952715347627),
#  ('Daenerys-Targaryen', 0.08627015537511595),
#  ('Robb-Stark', 0.07298399629664767),
#  ('Drogo', 0.06481224290874964),
#  ('Bran-Stark', 0.05579958811784442),
#  ('Sansa-Stark', 0.03714483664326785)]

# %%
# Weighted Betweenness similarity 
sorted(nx.betweenness_centrality(G1, weight='weight').items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [('Robert-Baratheon', 0.23341885664466297),
#  ('Eddard-Stark', 0.18703429235687297),
#  ('Tyrion-Lannister', 0.15311225972516293),
#  ('Robb-Stark', 0.1024018949825402),
#  ('Catelyn-Stark', 0.10169012330302643),
#  ('Jon-Snow', 0.09027684366394043),
#  ('Jaime-Lannister', 0.07745109164464009),
#  ('Rodrik-Cassel', 0.07667992877670296),
#  ('Drogo', 0.06894355184677767),
#  ('Jorah-Mormont', 0.0627085149665795)]

# %%
# Your observations here
#The betweenness measure is more different between weighted and non weighted than the previous m,easure of centrality. There are some strange results of adding the weight, such as Rodrick being in to top 10.

# %% [markdown]
# ## Is there a correlation between node centrality measures?
#
# Well, lets find out.
#
#
# - __Find the correlation between following:__
#     - Weighted Degree
#     - Closeness
#     - Weighted Betweenness
#     - Weighted Eigenvector
# - __Use book 1 for the analysis (You may choose other books as well)__
# - __Calculate correlation matrix and visualize the results for all characters__
# - __Comment on the results__

# %%
# Create a dataframe with 4 centrality measures, for all characters
dfcorr = pd.DataFrame.from_records([weighted_degree_centrality(G1),
                                  nx.closeness_centrality(G1),
                                  nx.betweenness_centrality(G1, weight='weight'), 
                                  nx.eigenvector_centrality(G1, weight='weight')])
dfcorr = dfcorr.T
dfcorr.columns = ['Degree', 'Closeness', 'Betweenness', 'Eigenvector']
dfcorr.head(10)
# Out:
#                                    Degree  Closeness  Betweenness  Eigenvector
# Addam-Marbrand                   0.000611   0.323478     0.000000     0.001551
# Aegon-I-Targaryen                0.000611   0.376518     0.000000     0.005096
# Aemon-Targaryen-(Maester-Aemon)  0.005023   0.336957     0.010753     0.013992
# Aerys-II-Targaryen               0.002512   0.385892     0.007183     0.027406
# Aggo                             0.002444   0.292913     0.000450     0.000852
# Albett                           0.000747   0.332143     0.007169     0.001875
# Alliser-Thorne                   0.005430   0.363281     0.026584     0.015771
# Alyn                             0.002172   0.380368     0.002693     0.019102
# Arthur-Dayne                     0.000272   0.275964     0.000000     0.000071
# Arya-Stark                       0.029188   0.458128     0.028114     0.143378

# %%
# plot the measures as lines to see if they correlate
plt.rcParams["figure.figsize"] = (20,8)
dfcorr.plot()
plt.legend(['Degree', 'Closeness', 'Betweenness', 'Eigenvector'], fontsize = 15)
plt.title ('Comparing Centrality measures - Correlation', fontsize=20 )
plt.show()

# %%
# calculate Correlation matrix
dfcorr.corr()
# Out:
#                                  Addam-Marbrand  Aegon-I-Targaryen  \
# Addam-Marbrand                         1.000000           0.999965
# Aegon-I-Targaryen                      0.999965           1.000000
# Aemon-Targaryen-(Maester-Aemon)        0.999777           0.999862
# Aerys-II-Targaryen                     0.998514           0.998929
# Aggo                                   0.999976           0.999893
# Albett                                 0.999801           0.999688
# Alliser-Thorne                         0.998679           0.998619
# Alyn                                   0.999254           0.999543
# Arthur-Dayne                           0.999992           0.999924
# Arya-Stark                             0.964805           0.966984
# Arys-Oakheart                          0.999999           0.999968
# Balon-Greyjoy                          0.999752           0.999754
# Balon-Swann                            0.999995           0.999943
# Barristan-Selmy                        0.971761           0.973710
# Benjen-Stark                           0.994387           0.994272
# Beric-Dondarrion                       0.999497           0.999493
# Boros-Blount                           0.999834           0.999951
# Bowen-Marsh                            0.999981           0.999996
# Bran-Stark                             0.978209           0.979909
# Brandon-Stark                          0.998681           0.999077
# Bronn                                  0.998011           0.998025
# Brynden-Tully                          0.998031           0.997886
# Catelyn-Stark                          0.958221           0.960353
# Cayn                                   0.999814           0.999941
# Cersei-Lannister                       0.891913           0.895687
# Chella                                 1.000000           0.999968
# Chett                                  0.999989           0.999933
# Chiggen                                0.999999           0.999968
# Clement-Piper                          0.999991           0.999920
# Clydas                                 0.999993           0.999926
# ...                                         ...                ...
# Stannis-Baratheon                      0.991213           0.992292
# Stevron-Frey                           0.999977           0.999924
# Stiv                                   0.999999           0.999975
# Syrio-Forel                            0.999587           0.999791
# Theon-Greyjoy                          0.996219           0.996231
# Thoros-of-Myr                          0.999993           0.999925
# Timett                                 0.999649           0.999500
# Tobho-Mott                             0.999839           0.999955
# Todder                                 0.999959           0.999993
# Tomard                                 0.998794           0.999171
# Tommen-Baratheon                       0.995557           0.995301
# Torrhen-Karstark                       0.999872           0.999873
# Tregar                                 0.999962           1.000000
# Tyrion-Lannister                       0.968210           0.969227
# Tytos-Blackwood                        0.999479           0.999313
# Tywin-Lannister                        0.994019           0.994770
# Ulf-son-of-Umar                        0.999992           0.999923
# Vardis-Egen                            0.999954           0.999991
# Varly                                  0.999962           1.000000
# Varys                                  0.947621           0.950276
# Vayon-Poole                            0.998810           0.999184
# Viserys-Targaryen                      0.999793           0.999884
# Walder-Frey                            0.995647           0.995325
# Waymar-Royce                           0.999967           0.999868
# Wendel-Manderly                        0.999402           0.999238
# Will-(prologue)                        0.999956           0.999855
# Willis-Wode                            0.999973           0.999931
# Wyl-(guard)                            0.999672           0.999589
# Wylla                                  0.999984           0.999996
# Yoren                                  0.999695           0.999662
#
#                                  Aemon-Targaryen-(Maester-Aemon)  \
# Addam-Marbrand                                          0.999777
# Aegon-I-Targaryen                                       0.999862
# Aemon-Targaryen-(Maester-Aemon)                         1.000000
# Aerys-II-Targaryen                                      0.999220
# Aggo                                                    0.999612
# Albett                                                  0.999721
# Alliser-Thorne                                          0.999208
# Alyn                                                    0.999611
# Arthur-Dayne                                            0.999727
# Arya-Stark                                              0.968249
# Arys-Oakheart                                           0.999800
# Balon-Greyjoy                                           0.999930
# Balon-Swann                                             0.999781
# Barristan-Selmy                                         0.974704
# Benjen-Stark                                            0.995661
# Beric-Dondarrion                                        0.999816
# Boros-Blount                                            0.999836
# Bowen-Marsh                                             0.999825
# Bran-Stark                                              0.981345
# Brandon-Stark                                           0.999230
# Bronn                                                   0.998845
# Brynden-Tully                                           0.998572
# Catelyn-Stark                                           0.963636
# Cayn                                                    0.999859
# Cersei-Lannister                                        0.897971
# Chella                                                  0.999794
# Chett                                                   0.999791
# Chiggen                                                 0.999767
# Clement-Piper                                           0.999718
# Clydas                                                  0.999725
# ...                                                          ...
# Stannis-Baratheon                                       0.992932
# Timett                                 0.999536  0.998419      0.999713
# Tobho-Mott                             0.998465  0.999785      0.999762
# Todder                                 0.998415  0.999522      0.999916
# Tomard                                 0.997444  0.999945      0.998599
# Tommen-Baratheon                       0.998959  0.993956      0.995726
# Torrhen-Karstark                       0.999329  0.999316      0.999861
# Tregar                                 0.998652  0.999552      0.999922
# Tyrion-Lannister                       0.977675  0.972679      0.967904
# Tytos-Blackwood                        0.999658  0.998184      0.999554
# Tywin-Lannister                        0.995332  0.996977      0.993700
# Ulf-son-of-Umar                        0.998723  0.999095      1.000000
# Vardis-Egen                            0.998391  0.999534      0.999909
# Varly                                  0.998652  0.999552      0.999922
# Varys                                  0.945089  0.959225      0.946382
# Vayon-Poole                            0.997149  0.999934      0.998612
# Viserys-Targaryen                      0.997726  0.999605      0.999716
# Walder-Frey                            0.998884  0.993738      0.995843
# Waymar-Royce                           0.998518  0.998924      0.999986
# Wendel-Manderly                        0.999720  0.998122      0.999478
# Will-(prologue)                        0.998385  0.998900      0.999973
# Willis-Wode                            0.999026  0.999209      0.999975
# Wyl-(guard)                            0.999650  0.998752      0.999707
# Wylla                                  0.998695  0.999455      0.999956
# Yoren                                  0.999640  0.999003      0.999707
#
#                                  Arya-Stark    ...     Vayon-Poole  \
# Addam-Marbrand                     0.964805    ...        0.998810
# Aegon-I-Targaryen                  0.966984    ...        0.999184
# Aemon-Targaryen-(Maester-Aemon)    0.968249    ...        0.999226
# Aerys-II-Targaryen                 0.977357    ...        0.999887
# Aggo                               0.963323    ...        0.998526
# Albett                             0.962075    ...        0.998098
# Alliser-Thorne                     0.962372    ...        0.997149
# Alyn                               0.974216    ...        0.999934
# Arthur-Dayne                       0.963782    ...        0.998612
# Arya-Stark                         1.000000    ...        0.976467
# Arys-Oakheart                      0.964932    ...        0.998830
# Balon-Greyjoy                      0.965555    ...        0.998692
# Balon-Swann                        0.964269    ...        0.998701
# Barristan-Selmy                    0.999578    ...        0.982112
# Benjen-Stark                       0.956122    ...        0.992339
# Beric-Dondarrion                   0.965079    ...        0.998370
# Boros-Blount                       0.969421    ...        0.999533
# Bowen-Marsh                        0.966374    ...        0.999088
# Bran-Stark                         0.997752    ...        0.986965
# Brandon-Stark                      0.976999    ...        0.999978
# Bronn                              0.963966    ...        0.996868
# Brynden-Tully                      0.959031    ...        0.995975
# Catelyn-Stark                      0.991195    ...        0.969110
# Cayn                               0.969697    ...        0.999564
# Cersei-Lannister                   0.979436    ...        0.912885
# Chella                             0.964919    ...        0.998829
# Chett                              0.964113    ...        0.998663
# Chiggen                            0.964959    ...        0.998840
# Clement-Piper                      0.963691    ...        0.998595
# Clydas                             0.963822    ...        0.998621
# ...                                     ...    ...             ...
# Stannis-Baratheon                  0.991071    ...        0.996454
# Stevron-Frey                       0.964178    ...        0.998659
# Stiv                               0.965161    ...        0.998874
# Syrio-Forel                        0.971919    ...        0.999797
# Theon-Greyjoy                      0.962001    ...        0.994975
# Thoros-of-Myr                      0.963799    ...        0.998616
# Timett                             0.960737    ...        0.997714
# Tobho-Mott                         0.969365    ...        0.999521
# Todder                             0.966948    ...        0.999182
# Tomard                             0.976518    ...        0.999981
# Tommen-Baratheon                   0.952956    ...        0.992750
# Torrhen-Karstark                   0.965685    ...        0.998830
# Tregar                             0.967041    ...        0.999191
# Tyrion-Lannister                   0.965389    ...        0.972304
# Tytos-Blackwood                    0.960028    ...        0.997428
# Tywin-Lannister                    0.983167    ...        0.997160
# Ulf-son-of-Umar                    0.963756    ...        0.998607
# Vardis-Egen                        0.967061    ...        0.999200
# Varly                              0.967041    ...        0.999191
# Varys                              0.998258    ...        0.962046
# Vayon-Poole                        0.976467    ...        1.000000
# Viserys-Targaryen                  0.968664    ...        0.999388
# Walder-Frey                        0.951016    ...        0.992474
# Waymar-Royce                       0.962804    ...        0.998420
# Wendel-Manderly                    0.960000    ...        0.997353
# Will-(prologue)                    0.962757    ...        0.998408
# Willis-Wode                        0.964515    ...        0.998717
# Wyl-(guard)                        0.962832    ...        0.998114
# Wylla                              0.966252    ...        0.999062
# Yoren                              0.964414    ...        0.998426
#
#                                  Viserys-Targaryen  Walder-Frey  Waymar-Royce  \
# Addam-Marbrand                            0.999793     0.995647      0.999967
# Aegon-I-Targaryen                         0.999884     0.995325      0.999868
# Aemon-Targaryen-(Maester-Aemon)           0.999575     0.996280      0.999590
# Aerys-II-Targaryen                        0.998971     0.993247      0.998046
# Aggo                                      0.999737     0.995479      0.999998
# Albett                                    0.999214     0.997299      0.999785
# Alliser-Thorne                            0.997726     0.998884      0.998518
# Alyn                                      0.999605     0.993738      0.998924
# Arthur-Dayne                              0.999716     0.995843      0.999986
# Arya-Stark                                0.968664     0.951016      0.962804
# Arys-Oakheart                             0.999786     0.995718      0.999959
# Balon-Greyjoy                             0.999313     0.997145      0.999622
# Balon-Swann                               0.999727     0.995915      0.999970
# Barristan-Selmy                           0.975302     0.958271      0.969987
# Benjen-Stark                              0.992598     0.999524      0.994117
# Beric-Dondarrion                          0.998916     0.997751      0.999343
# Boros-Blount                              0.999930     0.994671      0.999670
# Bowen-Marsh                               0.999882     0.995314      0.999906
# Bran-Stark                                0.980759     0.969157      0.976541
# Brandon-Stark                             0.999215     0.992786      0.998253
# Bronn                                     0.997035     0.998913      0.997749
# Brynden-Tully                             0.996789     0.999453      0.997916
# Catelyn-Stark                             0.960186     0.956140      0.955874
# Cayn                                      0.999905     0.994755      0.999637
# Cersei-Lannister                          0.898739     0.871345      0.888505
# Chella                                    0.999790     0.995694      0.999961
# Chett                                     0.999692     0.996058      0.999964
# Chiggen                                   0.999816     0.995534      0.999965
# Clement-Piper                             0.999712     0.995839      0.999988
# Clydas                                    0.999723     0.995813      0.999986
# ...                                            ...          ...           ...
# Stannis-Baratheon                         0.992964     0.982624      0.990171
# Stevron-Frey                              0.999651     0.996251      0.999942
# Stiv                                      0.999808     0.995632      0.999955
# Syrio-Forel                               0.999862     0.993929      0.999350
# Theon-Greyjoy                             0.994912     0.999212      0.995889
# Thoros-of-Myr                             0.999720     0.995825      0.999986
# Timett                                    0.998928     0.997733      0.999652
# Tobho-Mott                                0.999902     0.994877      0.999670
# Todder                                    0.999928     0.994992      0.999875
# Tomard                                    0.999295     0.992971      0.998383
# Tommen-Baratheon                          0.993719     0.999963      0.995457
# Torrhen-Karstark                          0.999519     0.996713      0.999762
# Tregar                                    0.999876     0.995376      0.999862
# Tyrion-Lannister                          0.966928     0.978539      0.966595
# Tytos-Blackwood                           0.998651     0.998114      0.999479
# Tywin-Lannister                           0.994445     0.991424      0.993112
# Ulf-son-of-Umar                           0.999715     0.995841      0.999986
# Vardis-Egen                               0.999935     0.994941      0.999868
# Varly                                     0.999876     0.995376      0.999862
# Varys                                     0.952322     0.932061      0.945191
# Vayon-Poole                               0.999388     0.992474      0.998420
# Viserys-Targaryen                         1.000000     0.993742      0.999686
# Walder-Frey                               0.993742     1.000000      0.995618
# Waymar-Royce                              0.999686     0.995618      1.000000
# Wendel-Manderly                           0.998541     0.998265      0.999393
# Will-(prologue)                           0.999704     0.995407      0.999997
# Willis-Wode                               0.999655     0.996277      0.999925
# Wyl-(guard)                               0.999039     0.997680      0.999608
# Wylla                                     0.999848     0.995523      0.999906
# Yoren                                     0.999155     0.997475      0.999587
#
#                                  Wendel-Manderly  Will-(prologue)  \
# Addam-Marbrand                          0.999402         0.999956
# Aegon-I-Targaryen                       0.999238         0.999855
# Aemon-Targaryen-(Maester-Aemon)         0.999441         0.999539
# Aerys-II-Targaryen                      0.997425         0.997999
# Aggo                                    0.999343         0.999997
# Albett                                  0.999893         0.999734
# Alliser-Thorne                          0.999720         0.998385
# Alyn                                    0.998122         0.998900
# Arthur-Dayne                            0.999478         0.999973
# Arya-Stark                              0.960000         0.962757
# Arys-Oakheart                           0.999425         0.999946
# Balon-Greyjoy                           0.999765         0.999558
# Balon-Swann                             0.999500         0.999954
# Barristan-Selmy                         0.967153         0.969962
# Benjen-Stark                            0.997210         0.993857
# Beric-Dondarrion                        0.999820         0.999255
# Boros-Blount                            0.998890         0.999660
# Bowen-Marsh                             0.999252         0.999897
# Bran-Stark                              0.975285         0.976427
# Brandon-Stark                           0.997374         0.998225
# Bronn                                   0.999274         0.997588
# Brynden-Tully                           0.999538         0.997762
# Catelyn-Stark                           0.957619         0.955513
# Cayn                                    0.998904         0.999623
# Cersei-Lannister                        0.884040         0.888437
# Chella                                  0.999417         0.999948
# Chett                                   0.999549         0.999944
# Chiggen                                 0.999359         0.999956
# Clement-Piper                           0.999477         0.999976
# Clydas                                  0.999468         0.999975
# ...                                          ...              ...
# Stannis-Baratheon                       0.988690         0.990127
# Stevron-Frey                            0.999610         0.999916
# Stiv                                    0.999391         0.999942
# Syrio-Forel                             0.998435         0.999342
# Theon-Greyjoy                           0.998230         0.995670
# Thoros-of-Myr                           0.999472         0.999974
# Timett                                  0.999964         0.999590
# Tobho-Mott                              0.998968         0.999655
# Todder                                  0.999116         0.999871
# Tomard                                  0.997520         0.998356
# Tommen-Baratheon                        0.998170         0.995236
# Torrhen-Karstark                        0.999688         0.999713
# Timett                              0.999799     0.999966  0.999579  0.999902
# Tobho-Mott                          0.999798     0.999411  0.999923  0.999540
# Todder                              0.999898     0.999488  0.999985  0.999561
# Tomard                              0.998744     0.998248  0.999054  0.998560
# Tommen-Baratheon                    0.996207     0.997638  0.995480  0.997478
# Torrhen-Karstark                    0.999954     0.999906  0.999894  0.999949
# Tregar                              0.999934     0.999603  0.999995  0.999677
# Tyrion-Lannister                    0.969654     0.972608  0.969097  0.973306
# Tytos-Blackwood                     0.999670     0.999946  0.999403  0.999869
# Tywin-Lannister                     0.994328     0.994584  0.994578  0.995144
# Ulf-son-of-Umar                     0.999974     0.999705  0.999955  0.999705
# Vardis-Egen                         0.999890     0.999472  0.999982  0.999547
# Varly                               0.999934     0.999603  0.999995  0.999677
# Varys                               0.947293     0.945360  0.949385  0.947275
# Vayon-Poole                         0.998717     0.998114  0.999062  0.998426
# Viserys-Targaryen                   0.999655     0.999039  0.999848  0.999155
# Walder-Frey                         0.996277     0.997680  0.995523  0.997475
# Waymar-Royce                        0.999925     0.999608  0.999906  0.999587
# Wendel-Manderly                     0.999612     0.999935  0.999330  0.999859
# Will-(prologue)                     0.999897     0.999538  0.999891  0.999517
# Willis-Wode                         1.000000     0.999831  0.999960  0.999847
# Wyl-(guard)                         0.999831     1.000000  0.999648  0.999982
# Wylla                               0.999960     0.999648  1.000000  0.999704
# Yoren                               0.999847     0.999982  0.999704  1.000000
#
# [187 rows x 187 columns]

# %%
# Your observations here 
#Closeness is the most different, least correlated to the other measures. The other three measurements seem correlated.

# %% [markdown]
# ## Character Evolution : Bring the the rest of series
#
# By Studying the change in centrality throughout the series, we can create an evolution of characters as the story progresses.
#
# - __Calculate the weighted degree centrality for all five books (edge lists), and save your results in a dataframe__
#
# Hint: Fill nans with zero for values that can not be calculated  due to being extremely small

# %%
# Create a character evolution dataframe based on weighted degree centrality from all books
graph_lst = [G1, G2, G3, G4, G5]
evol_degree = [weighted_degree_centrality(graph) for graph in graph_lst]

# Fill Nans and view contents
evol_degree_df = pd.DataFrame.from_records(evol_degree).fillna(0)
evol_degree_df
# Out:
#    Addam-Marbrand  Aegon-Frey-(son-of-Stevron)  Aegon-I-Targaryen  \
# 0        0.000611                     0.000000           0.000611
# 1        0.000000                     0.000000           0.001336
# 2        0.001711                     0.001062           0.000649
# 3        0.001908                     0.000000           0.000000
# 4        0.000000                     0.000000           0.000350
#
#    Aegon-Targaryen-(son-of-Rhaegar)  Aegon-V-Targaryen  \
# 0                          0.000000           0.000000
# 1                          0.000000           0.000236
# 2                          0.000177           0.000000
# 3                          0.000318           0.000318
# 4                          0.011386           0.000000
#
#    Aemon-Targaryen-(Dragonknight)  Aemon-Targaryen-(Maester-Aemon)  \
# 0                        0.000000                         0.005023
# 1                        0.000000                         0.002673
# 2                        0.000177                         0.009083
# 3                        0.000000                         0.009752
# 4                        0.000000                         0.003591
#
#    Aenys-Frey  Aeron-Greyjoy  Aerys-I-Targaryen    ...     Yellow-Dick  \
# 0    0.000000       0.000000           0.000000    ...        0.000000
# 1    0.000472       0.001730           0.000236    ...        0.000000
# 2    0.000000       0.000000           0.000000    ...        0.000000
# 3    0.000000       0.012932           0.000000    ...        0.000000
# 4    0.001139       0.000613           0.000000    ...        0.001314
#
#    Yezzan-zo-Qaggaz   Ygritte  Yohn-Royce    Yoren  Yorko-Terys    Ysilla  \
# 0          0.000000  0.000000    0.000000  0.00224     0.000000  0.000000
# 1          0.000000  0.001887    0.000000  0.00684     0.000000  0.000000
# 2          0.000000  0.007314    0.000177  0.00000     0.000000  0.000000
# 3          0.000000  0.000000    0.003922  0.00000     0.000636  0.000000
# 4          0.004204  0.001489    0.000000  0.00000     0.000000  0.004029
#
#    Yurkhaz-zo-Yunzak       Zei     Zollo
# 0            0.00000  0.000000  0.000000
# 1            0.00000  0.000000  0.000000
# 2            0.00000  0.000177  0.000472
# 3            0.00000  0.000000  0.000636
# 4            0.00035  0.000000  0.000000
#
# [5 rows x 796 columns]

# %% [markdown]
# - __Identify top 10 characters i.e. having 10 highest degree centrality values, from `evol_degree_df` and create a new dataframe with their names and centrality value__

# %%
pd.DataFrame.from_records(evol_degree_df).max(axis=0).sort_values(ascending=False)[0:10]
# Out:
# Eddard-Stark          0.087157
# Cersei-Lannister      0.082998
# Jon-Snow              0.066649
# Tyrion-Lannister      0.065173
# Robert-Baratheon      0.063875
# Daenerys-Targaryen    0.063146
# Jaime-Lannister       0.059148
# Joffrey-Baratheon     0.049450
# Bran-Stark            0.038208
# Sansa-Stark           0.036994
# dtype: float64

# %% [markdown]
# - __Plot the evolution of weighted degree centrality of the above characters over the 5 books__
# - __Comment on your answer__

# %%
evol_degree_df[list(pd.DataFrame.from_records(evol_degree_df).max(axis=0).sort_values(ascending=False)[0:10].index)].plot(figsize=(20,10))
plt.show()

# %%
# Your observations here 
#Ned drops off very quickly
#Cersei jumps from mid teir to the most central character
#Robert boratheon falls off very quickly as well
#This is a good measurement for when a character dies

# %% [markdown]
# #### Repeat Above for Weighted Betweenness Centrality

# %%
evol_betweenness = [nx.betweenness_centrality(graph, weight='weight') for graph in [G1, G2, G3, G4, G5]]
evol_betweenness_df = pd.DataFrame.from_records(evol_betweenness).fillna(0)
evol_betweenness_df[list(pd.DataFrame.from_records(evol_betweenness_df).max(axis=0).sort_values(ascending=False)[0:10].index)].plot(figsize=(20,10))
plt.show()

# %%
# Record Your observations here 
#Baelor blacktide seems anomalystic, may be due to the sept of Baelor becoming a pivitol plot point in the later books
#Baelor blacktide is correlated with Balon Greyjoty
#Weighting adds some strange trends
#Why are the greyjoys so overrepresented here?

# %% [markdown]
# ## Level Up: Visualize the Graphs (optional)
#
# - Use the techniques seen so far to visualize and customize the graphs
# - Study the shapes of the graphs in terms of spread , clusters etc and see if you can identify any links to the actual books (or the TV series)

# %% [markdown]
# ## Summary
#
# In this lab, we looked at different centrality measures of the graph data for the ASIOF dataset. We also compared these measures to see how they correlate with each other. We also saw in practice, the difference between taking the weighted centrality measures and how it may effect the results.
